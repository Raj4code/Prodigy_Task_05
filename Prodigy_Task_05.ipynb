# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv(r"C:\Users\hp\Downloads\RTA Dataset.csv\RTA Dataset.csv")
data
# Out:
#            Time Day_of_week Age_band_of_driver Sex_of_driver  \
# 0      17:02:00      Monday              18-30          Male
# 1      17:02:00      Monday              31-50          Male
# 2      17:02:00      Monday              18-30          Male
# 3       1:06:00      Sunday              18-30          Male
# 4       1:06:00      Sunday              18-30          Male
# ...         ...         ...                ...           ...
# 12311  16:15:00   Wednesday              31-50          Male
# 12312  18:00:00      Sunday            Unknown          Male
# 12313  13:55:00      Sunday            Over 51          Male
# 12314  13:55:00      Sunday              18-30        Female
# 12315  13:55:00      Sunday              18-30          Male
#
#         Educational_level Vehicle_driver_relation Driving_experience  \
# 0       Above high school                Employee              1-2yr
# 1      Junior high school                Employee         Above 10yr
# 2      Junior high school                Employee              1-2yr
# 3      Junior high school                Employee             5-10yr
# 4      Junior high school                Employee              2-5yr
# ...                   ...                     ...                ...
# 12311                 NaN                Employee              2-5yr
# 12312   Elementary school                Employee             5-10yr
# 12313  Junior high school                Employee             5-10yr
# 12314  Junior high school                Employee         Above 10yr
# 12315  Junior high school                Employee             5-10yr
#
#            Type_of_vehicle Owner_of_vehicle Service_year_of_vehicle  ...  \
# 0               Automobile            Owner              Above 10yr  ...
# 1      Public (> 45 seats)            Owner                 5-10yrs  ...
# 2          Lorry (41?100Q)            Owner                     NaN  ...
# 3      Public (> 45 seats)     Governmental                     NaN  ...
# 4                      NaN            Owner                 5-10yrs  ...
# ...                    ...              ...                     ...  ...
# 12311       Lorry (11?40Q)            Owner                     NaN  ...
# 12312           Automobile            Owner                     NaN  ...
# 12313                Bajaj            Owner                  2-5yrs  ...
# 12314      Lorry (41?100Q)            Owner                  2-5yrs  ...
# 12315                Other            Owner                  2-5yrs  ...
#
#       Vehicle_movement   Casualty_class Sex_of_casualty Age_band_of_casualty  \
# 0       Going straight               na              na                   na
# 1       Going straight               na              na                   na
# 2       Going straight  Driver or rider            Male                31-50
# 3       Going straight       Pedestrian          Female                18-30
# 4       Going straight               na              na                   na
# ...                ...              ...             ...                  ...
# 12311   Going straight               na              na                   na
# 12312            Other               na              na                   na
# 12313            Other  Driver or rider            Male                31-50
# 12314            Other               na              na                   na
# 12315         Stopping       Pedestrian          Female                    5
#
#       Casualty_severity Work_of_casuality Fitness_of_casuality  \
# 0                    na               NaN                  NaN
# 1                    na               NaN                  NaN
# 2                     3            Driver                  NaN
# 3                     3            Driver               Normal
# 4                    na               NaN                  NaN
# ...                 ...               ...                  ...
# 12311                na            Driver               Normal
# 12312                na            Driver               Normal
# 12313                 3            Driver               Normal
# 12314                na            Driver               Normal
# 12315                 3            Driver               Normal
#
#                                      Pedestrian_movement  \
# 0                                       Not a Pedestrian
# 1                                       Not a Pedestrian
# 2                                       Not a Pedestrian
# 3                                       Not a Pedestrian
# 4                                       Not a Pedestrian
# ...                                                  ...
# 12311                                   Not a Pedestrian
# 12312                                   Not a Pedestrian
# 12313                                   Not a Pedestrian
# 12314                                   Not a Pedestrian
# 12315  Crossing from nearside - masked by parked or s...
#
#                           Cause_of_accident Accident_severity
# 0                           Moving Backward     Slight Injury
# 1                                Overtaking     Slight Injury
# 2                 Changing lane to the left    Serious Injury
# 3                Changing lane to the right     Slight Injury
# 4                                Overtaking     Slight Injury
# ...                                     ...               ...
# 12311                         No distancing     Slight Injury
# 12312                         No distancing     Slight Injury
# 12313            Changing lane to the right    Serious Injury
# 12314  Driving under the influence of drugs     Slight Injury
# 12315            Changing lane to the right     Slight Injury
#
# [12316 rows x 32 columns]

# %%
# To view the top 5 rows of the dataset
data.head()
# Out:
#        Time Day_of_week Age_band_of_driver Sex_of_driver   Educational_level  \
# 0  17:02:00      Monday              18-30          Male   Above high school
# 1  17:02:00      Monday              31-50          Male  Junior high school
# 2  17:02:00      Monday              18-30          Male  Junior high school
# 3   1:06:00      Sunday              18-30          Male  Junior high school
# 4   1:06:00      Sunday              18-30          Male  Junior high school
#
#   Vehicle_driver_relation Driving_experience      Type_of_vehicle  \
# 0                Employee              1-2yr           Automobile
# 1                Employee         Above 10yr  Public (> 45 seats)
# 2                Employee              1-2yr      Lorry (41?100Q)
# 3                Employee             5-10yr  Public (> 45 seats)
# 4                Employee              2-5yr                  NaN
#
#   Owner_of_vehicle Service_year_of_vehicle  ... Vehicle_movement  \
# 0            Owner              Above 10yr  ...   Going straight
# 1            Owner                 5-10yrs  ...   Going straight
# 2            Owner                     NaN  ...   Going straight
# 3     Governmental                     NaN  ...   Going straight
# 4            Owner                 5-10yrs  ...   Going straight
#
#     Casualty_class Sex_of_casualty Age_band_of_casualty Casualty_severity  \
# 0               na              na                   na                na
# 1               na              na                   na                na
# 2  Driver or rider            Male                31-50                 3
# 3       Pedestrian          Female                18-30                 3
# 4               na              na                   na                na
#
#   Work_of_casuality Fitness_of_casuality Pedestrian_movement  \
# 0               NaN                  NaN    Not a Pedestrian
# 1               NaN                  NaN    Not a Pedestrian
# 2            Driver                  NaN    Not a Pedestrian
# 3            Driver               Normal    Not a Pedestrian
# 4               NaN                  NaN    Not a Pedestrian
#
#             Cause_of_accident Accident_severity
# 0             Moving Backward     Slight Injury
# 1                  Overtaking     Slight Injury
# 2   Changing lane to the left    Serious Injury
# 3  Changing lane to the right     Slight Injury
# 4                  Overtaking     Slight Injury
#
# [5 rows x 32 columns]

# %%
# To know the number of rows and columns of the dataset.
data.shape
# Out:
# (12316, 32)

# %%
data.columns
# Out:
# Index(['Time', 'Day_of_week', 'Age_band_of_driver', 'Sex_of_driver',
#        'Educational_level', 'Vehicle_driver_relation', 'Driving_experience',
#        'Type_of_vehicle', 'Owner_of_vehicle', 'Service_year_of_vehicle',
#        'Defect_of_vehicle', 'Area_accident_occured', 'Lanes_or_Medians',
#        'Road_allignment', 'Types_of_Junction', 'Road_surface_type',
#        'Road_surface_conditions', 'Light_conditions', 'Weather_conditions',
#        'Type_of_collision', 'Number_of_vehicles_involved',
#        'Number_of_casualties', 'Vehicle_movement', 'Casualty_class',
#        'Sex_of_casualty', 'Age_band_of_casualty', 'Casualty_severity',
#        'Work_of_casuality', 'Fitness_of_casuality', 'Pedestrian_movement',
#        'Cause_of_accident', 'Accident_severity'],
#       dtype='object')

# %%
data.isnull().sum ()
# Out:
# Time                              0
# Day_of_week                       0
# Age_band_of_driver                0
# Sex_of_driver                     0
# Educational_level               741
# Vehicle_driver_relation         579
# Driving_experience              829
# Type_of_vehicle                 950
# Owner_of_vehicle                482
# Service_year_of_vehicle        3928
# Defect_of_vehicle              4427
# Area_accident_occured           239
# Lanes_or_Medians                385
# Road_allignment                 142
# Types_of_Junction               887
# Road_surface_type               172
# Road_surface_conditions           0
# Light_conditions                  0
# Weather_conditions                0
# Type_of_collision               155
# Number_of_vehicles_involved       0
# Number_of_casualties              0
# Vehicle_movement                308
# Casualty_class                    0
# Sex_of_casualty                   0
# Age_band_of_casualty              0
# Casualty_severity                 0
# Work_of_casuality              3198
# Fitness_of_casuality           2635
# Pedestrian_movement               0
# Cause_of_accident                 0
# Accident_severity                 0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data['Time']= pd.to_datetime(data['Time'])
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_14020\4145591858.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   data['Time']= pd.to_datetime(data['Time'])

# %% [markdown]
# ### Statistical Analysis:

# %%
data.describe(include="all")
# Out:
#                                  Time Day_of_week Age_band_of_driver  \
# count                           12316       12316              12316
# unique                            NaN           7                  5
# top                               NaN      Friday              18-30
# freq                              NaN        2041               4271
# mean    2024-07-24 14:17:50.768106752         NaN                NaN
# min               2024-07-24 00:01:00         NaN                NaN
# 25%               2024-07-24 10:31:00         NaN                NaN
# 50%               2024-07-24 15:10:00         NaN                NaN
# 75%               2024-07-24 18:10:00         NaN                NaN
# max               2024-07-24 23:59:00         NaN                NaN
# std                               NaN         NaN                NaN
#
#        Sex_of_driver   Educational_level Vehicle_driver_relation  \
# count          12316               11575                   11737
# unique             3                   7                       4
# top             Male  Junior high school                Employee
# freq           11437                7619                    9627
# mean             NaN                 NaN                     NaN
# min              NaN                 NaN                     NaN
# 25%              NaN                 NaN                     NaN
# 50%              NaN                 NaN                     NaN
# 75%              NaN                 NaN                     NaN
# max              NaN                 NaN                     NaN
# std              NaN                 NaN                     NaN
#
#        Driving_experience Type_of_vehicle Owner_of_vehicle  \
# count               11487           11366            11834
# unique                  7              17                4
# top                5-10yr      Automobile            Owner
# freq                 3363            3205            10459
# mean                  NaN             NaN              NaN
# min                   NaN             NaN              NaN
# 25%                   NaN             NaN              NaN
# 50%                   NaN             NaN              NaN
# 75%                   NaN             NaN              NaN
# max                   NaN             NaN              NaN
# std                   NaN             NaN              NaN
#
#        Service_year_of_vehicle  ... Vehicle_movement   Casualty_class  \
# count                     8388  ...            12008            12316
# unique                       6  ...               13                4
# top                    Unknown  ...   Going straight  Driver or rider
# freq                      2883  ...             8158             4944
# mean                       NaN  ...              NaN              NaN
# min                        NaN  ...              NaN              NaN
# 25%                        NaN  ...              NaN              NaN
# 50%                        NaN  ...              NaN              NaN
# 75%                        NaN  ...              NaN              NaN
# max                        NaN  ...              NaN              NaN
# std                        NaN  ...              NaN              NaN
#
#        Sex_of_casualty Age_band_of_casualty Casualty_severity  \
# count            12316                12316             12316
# unique               3                    6                 4
# top               Male                   na                 3
# freq              5253                 4443              7076
# mean               NaN                  NaN               NaN
# min                NaN                  NaN               NaN
# 25%                NaN                  NaN               NaN
# 50%                NaN                  NaN               NaN
# 75%                NaN                  NaN               NaN
# max                NaN                  NaN               NaN
# std                NaN                  NaN               NaN
#
#        Work_of_casuality Fitness_of_casuality Pedestrian_movement  \
# count               9118                 9681               12316
# unique                 7                    5                   9
# top               Driver               Normal    Not a Pedestrian
# freq                5903                 9608               11390
# mean                 NaN                  NaN                 NaN
# min                  NaN                  NaN                 NaN
# 25%                  NaN                  NaN                 NaN
# 50%                  NaN                  NaN                 NaN
# 75%                  NaN                  NaN                 NaN
# max                  NaN                  NaN                 NaN
# std                  NaN                  NaN                 NaN
#
#        Cause_of_accident Accident_severity
# count              12316             12316
# unique                20                 3
# top        No distancing     Slight Injury
# freq                2263             10415
# mean                 NaN               NaN
# min                  NaN               NaN
# 25%                  NaN               NaN
# 50%                  NaN               NaN
# 75%                  NaN               NaN
# max                  NaN               NaN
# std                  NaN               NaN
#
# [11 rows x 32 columns]

# %%
data.groupby('Accident_severity').size()
# Out:
# Accident_severity
# Fatal injury        158
# Serious Injury     1743
# Slight Injury     10415
# dtype: int64

# %%
data['Number_of_casualties'].value_counts()
# Out:
# Number_of_casualties
# 1    8397
# 2    2290
# 3     909
# 4     394
# 5     207
# 6      89
# 7      22
# 8       8
# Name: count, dtype: int64

# %% [markdown]
# ### Exploratory Data Analysis:

# %%
plt.figure(figsize=(10,7))
sns.boxplot(data=data, y='Number_of_vehicles_involved', x='Number_of_casualties')
plt.show()

# %%
sns.boxplot(data=data, y='Number_of_casualties')
plt.show()

# %%
sns.boxplot(data=data, y='Number_of_vehicles_involved')
plt.show()

# %%
    sns.scatterplot(x=data['Number_of_vehicles_involved'], y=data['Number_of_casualties'])
plt.show()

# %%
sns.pairplot(data[['Number_of_vehicles_involved','Number_of_casualties']])
plt.show()
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
correlation_matrix = data[['Number_of_vehicles_involved','Number_of_casualties']].corr()
sns.heatmap(correlation_matrix, annot=True)
plt.show()

# %%
plt.figure(figsize=(10,7))
plt.pie(x=data['Accident_severity'].value_counts().values,
        labels=data['Accident_severity'].value_counts().index,
        autopct='%2.2f%%')
plt.show()

# %%
grid = sns.FacetGrid(data=data, col='Accident_severity', height=4, aspect=1, sharey=False)
grid.map(sns.countplot, 'Number_of_vehicles_involved', palette=['black', 'brown', 'orange'])
plt.show()
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\axisgrid.py:712: UserWarning: Using the countplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %%
lists=['Vehicle_driver_relation', 'Work_of_casuality', 'Fitness_of_casuality','Day_of_week','Casualty_severity','Time','Sex_of_driver','Educational_level','Defect_of_vehicle','Owner_of_vehicle','Service_year_of_vehicle', 'Road_surface_type','Sex_of_casualty']
data.drop(columns = lists, inplace=True)

# %%
data.shape
# Out:
# (12316, 19)

# %%
data.columns
# Out:
# Index(['Age_band_of_driver', 'Driving_experience', 'Type_of_vehicle',
#        'Area_accident_occured', 'Lanes_or_Medians', 'Road_allignment',
#        'Types_of_Junction', 'Road_surface_conditions', 'Light_conditions',
#        'Weather_conditions', 'Type_of_collision',
#        'Number_of_vehicles_involved', 'Number_of_casualties',
#        'Vehicle_movement', 'Casualty_class', 'Age_band_of_casualty',
#        'Pedestrian_movement', 'Cause_of_accident', 'Accident_severity'],
#       dtype='object')

# %%
# fill missing values with mean column values
data['Driving_experience'].fillna(data['Driving_experience'].mode()[0], inplace=True)
data['Type_of_vehicle'].fillna(data['Type_of_vehicle'].mode()[0], inplace=True)
data['Area_accident_occured'].fillna(data['Area_accident_occured'].mode()[0], inplace=True)
data['Road_allignment'].fillna(data['Road_allignment'].mode()[0], inplace=True)
data['Type_of_collision'].fillna(data['Type_of_collision'].mode()[0], inplace=True)
data['Vehicle_movement'].fillna(data['Vehicle_movement'].mode()[0], inplace=True)
data['Lanes_or_Medians'].fillna(data['Lanes_or_Medians'].mode()[0], inplace=True)
data['Types_of_Junction'].fillna(data['Types_of_Junction'].mode()[0], inplace=True)

# %%
data.isnull().sum()
# Out:
# Age_band_of_driver             0
# Driving_experience             0
# Type_of_vehicle                0
# Area_accident_occured          0
# Lanes_or_Medians               0
# Road_allignment                0
# Types_of_Junction              0
# Road_surface_conditions        0
# Light_conditions               0
# Weather_conditions             0
# Type_of_collision              0
# Number_of_vehicles_involved    0
# Number_of_casualties           0
# Vehicle_movement               0
# Casualty_class                 0
# Age_band_of_casualty           0
# Pedestrian_movement            0
# Cause_of_accident              0
# Accident_severity              0
# dtype: int64

# %%
target_count = data['Accident_severity'].value_counts()
print('Class 0:', target_count[0])
print('Class 1:', target_count[1])
print('Proportion:', round(target_count[0] / target_count[1], 2), ': 1')

target_count.plot(kind='bar', title='Count (target)');
# Out:
# Class 0: 10415
# Class 1: 1743
# Proportion: 5.98 : 1
# C:\Users\hp\AppData\Local\Temp\ipykernel_14020\4061650690.py:2: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   print('Class 0:', target_count[0])
# C:\Users\hp\AppData\Local\Temp\ipykernel_14020\4061650690.py:3: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   print('Class 1:', target_count[1])
# C:\Users\hp\AppData\Local\Temp\ipykernel_14020\4061650690.py:4: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   print('Proportion:', round(target_count[0] / target_count[1], 2), ': 1')

# %%
from sklearn.preprocessing import LabelEncoder           
LE = LabelEncoder()
data=data.apply(LE.fit_transform)

# %%
data.corr()
# Out:
#                              Age_band_of_driver  Driving_experience  \
# Age_band_of_driver                     1.000000           -0.013407
# Driving_experience                    -0.013407            1.000000
# Type_of_vehicle                        0.004830            0.014333
# Area_accident_occured                  0.011472           -0.000290
# Lanes_or_Medians                       0.008176           -0.010444
# Road_allignment                        0.000486           -0.015602
# Types_of_Junction                     -0.028025            0.009245
# Road_surface_conditions               -0.032533           -0.003696
# Light_conditions                      -0.007766           -0.015577
# Weather_conditions                     0.025482           -0.000084
# Type_of_collision                      0.000496            0.012574
# Number_of_vehicles_involved            0.001690           -0.008222
# Number_of_casualties                  -0.054474           -0.007118
# Vehicle_movement                      -0.006562            0.004794
# Casualty_class                         0.005386           -0.002783
# Age_band_of_casualty                   0.000043           -0.010891
# Pedestrian_movement                    0.000372           -0.018790
# Cause_of_accident                     -0.000703           -0.007728
# Accident_severity                      0.013185            0.000509
#
#                              Type_of_vehicle  Area_accident_occured  \
# Age_band_of_driver                  0.004830               0.011472
# Driving_experience                  0.014333              -0.000290
# Type_of_vehicle                     1.000000              -0.007631
# Area_accident_occured              -0.007631               1.000000
# Lanes_or_Medians                   -0.020156               0.022760
# Road_allignment                    -0.020910              -0.025859
# Types_of_Junction                  -0.005553               0.014580
# Road_surface_conditions             0.019018              -0.007290
# Light_conditions                   -0.003739              -0.013597
# Weather_conditions                  0.006903               0.003127
# Type_of_collision                   0.025911              -0.003940
# Number_of_vehicles_involved         0.001140              -0.016498
# Number_of_casualties                0.003022              -0.004690
# Vehicle_movement                    0.010841               0.004691
# Casualty_class                     -0.006116               0.011325
# Age_band_of_casualty               -0.008934               0.008001
# Pedestrian_movement                 0.010500               0.000949
# Cause_of_accident                  -0.004200              -0.009589
# Accident_severity                  -0.003709              -0.018374
#
#                              Lanes_or_Medians  Road_allignment  \
# Age_band_of_driver                   0.008176         0.000486
# Driving_experience                  -0.010444        -0.015602
# Type_of_vehicle                     -0.020156        -0.020910
# Area_accident_occured                0.022760        -0.025859
# Lanes_or_Medians                     1.000000         0.042815
# Road_allignment                      0.042815         1.000000
# Types_of_Junction                   -0.002125         0.007188
# Road_surface_conditions              0.011774        -0.000918
# Light_conditions                     0.004624         0.005625
# Weather_conditions                   0.005828         0.018304
# Type_of_collision                    0.007008         0.020418
# Number_of_vehicles_involved         -0.001199        -0.001536
# Number_of_casualties                 0.002188        -0.011434
# Vehicle_movement                    -0.002089        -0.004267
# Casualty_class                       0.006034        -0.003117
# Age_band_of_casualty                 0.006677         0.005540
# Pedestrian_movement                  0.005848         0.005219
# Cause_of_accident                    0.016384        -0.000287
# Accident_severity                   -0.011844        -0.005967
#
#                              Types_of_Junction  Road_surface_conditions  \
# Age_band_of_driver                   -0.028025                -0.032533
# Driving_experience                    0.009245                -0.003696
# Type_of_vehicle                      -0.005553                 0.019018
# Area_accident_occured                 0.014580                -0.007290
# Lanes_or_Medians                     -0.002125                 0.011774
# Road_allignment                       0.007188                -0.000918
# Types_of_Junction                     1.000000                 0.004724
# Road_surface_conditions               0.004724                 1.000000
# Light_conditions                      0.037063                -0.198447
# Weather_conditions                   -0.001816                 0.400485
# Type_of_collision                     0.007516                 0.000456
# Number_of_vehicles_involved          -0.020214                -0.020963
# Number_of_casualties                 -0.043389                 0.072828
# Vehicle_movement                     -0.010761                -0.004667
# Casualty_class                        0.002423                -0.002313
# Age_band_of_casualty                  0.007946                 0.006415
# Pedestrian_movement                  -0.008855                 0.006157
# Cause_of_accident                    -0.006561                 0.002811
# Accident_severity                    -0.008861                 0.004579
#
#                              Light_conditions  Weather_conditions  \
# Age_band_of_driver                  -0.007766            0.025482
# Driving_experience                  -0.015577           -0.000084
# Type_of_vehicle                     -0.003739            0.006903
# Area_accident_occured               -0.013597            0.003127
# Lanes_or_Medians                     0.004624            0.005828
# Road_allignment                      0.005625            0.018304
# Types_of_Junction                    0.037063           -0.001816
# Road_surface_conditions             -0.198447            0.400485
# Light_conditions                     1.000000           -0.067367
# Weather_conditions                  -0.067367            1.000000
# Type_of_collision                    0.014883           -0.013347
# Number_of_vehicles_involved          0.032493           -0.037733
# Number_of_casualties                -0.055116            0.014138
# Vehicle_movement                     0.022327            0.007648
# Casualty_class                      -0.012499            0.003313
# Age_band_of_casualty                -0.011780           -0.002245
# Pedestrian_movement                  0.014229            0.018292
# Cause_of_accident                    0.004213            0.001320
# Accident_severity                    0.025741            0.010172
#
#                              Type_of_collision  Number_of_vehicles_involved  \
# Age_band_of_driver                    0.000496                     0.001690
# Driving_experience                    0.012574                    -0.008222
# Type_of_vehicle                       0.025911                     0.001140
# Area_accident_occured                -0.003940                    -0.016498
# Lanes_or_Medians                      0.007008                    -0.001199
# Road_allignment                       0.020418                    -0.001536
# Types_of_Junction                     0.007516                    -0.020214
# Road_surface_conditions               0.000456                    -0.020963
# Light_conditions                      0.014883                     0.032493
# Weather_conditions                   -0.013347                    -0.037733
# Type_of_collision                     1.000000                     0.007304
# Number_of_vehicles_involved           0.007304                     1.000000
# Number_of_casualties                 -0.020694                     0.220531
# Vehicle_movement                      0.000640                    -0.004480
# Casualty_class                        0.012333                     0.005281
# Age_band_of_casualty                  0.004962                     0.001796
# Pedestrian_movement                  -0.008081                     0.021109
# Cause_of_accident                     0.011757                    -0.021815
# Accident_severity                     0.025867                     0.100205
#
#                              Number_of_casualties  Vehicle_movement  \
# Age_band_of_driver                      -0.054474         -0.006562
# Driving_experience                      -0.007118          0.004794
# Type_of_vehicle                          0.003022          0.010841
# Area_accident_occured                   -0.004690          0.004691
# Lanes_or_Medians                         0.002188         -0.002089
# Road_allignment                         -0.011434         -0.004267
# Types_of_Junction                       -0.043389         -0.010761
# Road_surface_conditions                  0.072828         -0.004667
# Light_conditions                        -0.055116          0.022327
# Weather_conditions                       0.014138          0.007648
# Type_of_collision                       -0.020694          0.000640
# Number_of_vehicles_involved              0.220531         -0.004480
# Number_of_casualties                     1.000000          0.002599
# Vehicle_movement                         0.002599          1.000000
# Casualty_class                          -0.012820          0.001281
# Age_band_of_casualty                    -0.008637          0.006919
# Pedestrian_movement                      0.006019         -0.008456
# Cause_of_accident                       -0.022096          0.002336
# Accident_severity                       -0.045339         -0.010386
#
#                              Casualty_class  Age_band_of_casualty  \
# Age_band_of_driver                 0.005386              0.000043
# Driving_experience                -0.002783             -0.010891
# Type_of_vehicle                   -0.006116             -0.008934
# Area_accident_occured              0.011325              0.008001
# Lanes_or_Medians                   0.006034              0.006677
# Road_allignment                   -0.003117              0.005540
# Types_of_Junction                  0.002423              0.007946
# Road_surface_conditions           -0.002313              0.006415
# Light_conditions                  -0.012499             -0.011780
# Weather_conditions                 0.003313             -0.002245
# Type_of_collision                  0.012333              0.004962
# Number_of_vehicles_involved        0.005281              0.001796
# Number_of_casualties              -0.012820             -0.008637
# Vehicle_movement                   0.001281              0.006919
# Casualty_class                     1.000000              0.802169
# Age_band_of_casualty               0.802169              1.000000
# Pedestrian_movement               -0.075248              0.062065
# Cause_of_accident                  0.011625              0.010536
# Accident_severity                  0.014075              0.025510
#
#                              Pedestrian_movement  Cause_of_accident  \
# Age_band_of_driver                      0.000372          -0.000703
# Driving_experience                     -0.018790          -0.007728
# Type_of_vehicle                         0.010500          -0.004200
# Area_accident_occured                   0.000949          -0.009589
# Lanes_or_Medians                        0.005848           0.016384
# Road_allignment                         0.005219          -0.000287
# Types_of_Junction                      -0.008855          -0.006561
# Road_surface_conditions                 0.006157           0.002811
# Light_conditions                        0.014229           0.004213
# Weather_conditions                      0.018292           0.001320
# Type_of_collision                      -0.008081           0.011757
# Number_of_vehicles_involved             0.021109          -0.021815
# Number_of_casualties                    0.006019          -0.022096
# Vehicle_movement                       -0.008456           0.002336
# Casualty_class                         -0.075248           0.011625
# Age_band_of_casualty                    0.062065           0.010536
# Pedestrian_movement                     1.000000           0.001523
# Cause_of_accident                       0.001523           1.000000
# Accident_severity                       0.013082           0.008040
#
#                              Accident_severity
# Age_band_of_driver                    0.013185
# Driving_experience                    0.000509
# Type_of_vehicle                      -0.003709
# Area_accident_occured                -0.018374
# Lanes_or_Medians                     -0.011844
# Road_allignment                      -0.005967
# Types_of_Junction                    -0.008861
# Road_surface_conditions               0.004579
# Light_conditions                      0.025741
# Weather_conditions                    0.010172
# Type_of_collision                     0.025867
# Number_of_vehicles_involved           0.100205
# Number_of_casualties                 -0.045339
# Vehicle_movement                     -0.010386
# Casualty_class                        0.014075
# Age_band_of_casualty                  0.025510
# Pedestrian_movement                   0.013082
# Cause_of_accident                     0.008040
# Accident_severity                     1.000000

# %%
plt.figure(figsize=[25,15])
sns.heatmap(data.corr(),annot=True)
# Out:
# <Axes: >
